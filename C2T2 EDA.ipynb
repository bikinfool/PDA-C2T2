# %%
import numpy as np
import pandas as pd
import pandas_profiling
import tkinter
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('TkAgg')
# %matplotlib inline

header = ['LIMIT_BAL', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1' , 'PAY_2' , 'PAY_3' , 'PAY_4' , 'PAY_5' ,
           'PAY_6' , 'BILL_AMT6' , 'BILL_AMT5' , 'BILL_AMT4' , 'BILL_AMT3' , 'BILL_AMT2' , 
           'BILL_AMT1' , 'PAY_AMT6' , 'PAY_AMT5' , 'PAY_AMT4' , 'PAY_AMT3' , 'PAY_AMT2' , 'PAY_AMT1',
           'default payment next month']
print(header[1])
# Out:
# EDUCATION

# %%
from pandas_profiling import ProfileReport

# %%
Cdata = pd.read_csv( f"c:\\users\johne\Documents\Purdue DA\------How to Program\Credit_one_C.csv")
#data = data.drop_duplicates()
Cdata.head()
# Out:
#    LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000  female  university         1   24      2      2     -1     -1
# 1     120000  female  university         2   26     -1      2      0      0
# 2      90000  female  university         2   34      0      0      0      0
# 3      50000  female  university         1   37      0      0      0      0
# 4      50000    male  university         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT3  BILL_AMT2  BILL_AMT1  PAY_AMT6  PAY_AMT5  PAY_AMT4  \
# 0     -2  ...        689       3102       3913         0         0         0
# 1      0  ...       2682       1725       2682      2000         0      1000
# 2      0  ...      13559      14027      29239      5000      1000      1000
# 3      0  ...      49291      48233      46990      1000      1069      1100
# 4      0  ...      35835       5670       8617       679       689      9000
#
# ...

# %%
Cdata.describe()
# Out:
#             LIMIT_BAL      MARRIAGE           AGE         PAY_1         PAY_2  \
# count    29965.000000  29965.000000  29965.000000  29965.000000  29965.000000
# mean    167442.005006      1.551877     35.487969     -0.016753     -0.131854
# std     129760.135222      0.521997      9.219459      1.123492      1.196322
# min      10000.000000      0.000000     21.000000     -2.000000     -2.000000
# 25%      50000.000000      1.000000     28.000000     -1.000000     -1.000000
# 50%     140000.000000      2.000000     34.000000      0.000000      0.000000
# 75%     240000.000000      2.000000     41.000000      0.000000      0.000000
# max    1000000.000000      3.000000     79.000000      8.000000      8.000000
#
#               PAY_3         PAY_4         PAY_5         PAY_6      BILL_AMT6  \
# count  29965.000000  29965.000000  29965.000000  29965.000000   29965.000000
# mean      -0.164392     -0.218922     -0.264509     -0.289438   38917.012281
# ...

# %%
# typed into anaconda, should not need to run each time.

#pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
# What is difference between the following two lines, and that recommended by Mike?

# This first line generates and displays (on screen) the report.
# The second croates an object (profile) and then allows you to save it to a file in html or json format
# Analysis file saved and included in github

#--------pandas_profiling.ProfileReport(Cdata)------

profile = pandas_profiling.ProfileReport(Cdata)
profile.to_file("c:\\users\johne\Documents\Purdue DA\Analysis.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#Change sex, education and default to 1's/0's (integer)
# This analysis was not used. Too many variables.

creditD = pd.get_dummies(Cdata)
creditD.dtypes
# Out:
# LIMIT_BAL                                 int64
# MARRIAGE                                  int64
# AGE                                       int64
# PAY_1                                     int64
# PAY_2                                     int64
# PAY_3                                     int64
# PAY_4                                     int64
# PAY_5                                     int64
# PAY_6                                     int64
# BILL_AMT6                                 int64
# BILL_AMT5                                 int64
# BILL_AMT4                                 int64
# BILL_AMT3                                 int64
# BILL_AMT2                                 int64
# BILL_AMT1                                 int64
# PAY_AMT6                                  int64
# PAY_AMT5                                  int64
# PAY_AMT4                                  int64
# PAY_AMT3                                  int64
# PAY_AMT2                                  int64
# ...

# %%
# hist_plot = [header[0], header[2],header[1], header[3], header [7]]   # note any order
# print(hist_plot)
# for i in range(len(hist_plot)):
#     name = str(hist_plot[i])
#     plt.hist(Cdata[name], bins=4)
#     plt.title(f'Credit One Data histogram of {name}')
#     plt.ylabel('Quantity')
#     plt.show()

plt.hist(Cdata['LIMIT_BAL'], bins=10)
plt.title('Credit One Data histogram of Limit_BAL')
plt.ylabel('Quantity')
plt.show()

plt.hist(Cdata['AGE'], bins=10)
plt.title('Credit One Data histogram of Age')
plt.ylabel('Quantity')
plt.show()

plt.hist(Cdata['EDUCATION'], bins=4)
plt.title('Credit One Data histogram of Education')
plt.ylabel('Quantity')
plt.show()

plt.hist(Cdata['SEX'], bins=2)
plt.title('Credit One Data histogram of Sex')
plt.ylabel('Quantity')
plt.show()

plt.hist(Cdata['default payment next month'], bins=2)
plt.title('Credit One Data histogram of default payment next month')
plt.ylabel('Quantity')
plt.show()

# %%
#no corelation age vs limit balance
x = Cdata['AGE']
y = Cdata['LIMIT_BAL']
plt.scatter(x,y)
plt.show()

# %%
x = Cdata['SEX']
y = Cdata['default payment next month']
plt.scatter(x,y)
plt.show()
# yeah this did not show ANYTHING !!!!!!!!! got a good laugh though

# %%
#Limit balance vs default, no correlation
x = Cdata['LIMIT_BAL']
y = Cdata['default payment next month']
plt.scatter(x,y)
plt.show()

# %%
#Drop some columns, look at just variables that are data pre-credit approval
Cor_data = Cdata.drop(axis=1, columns=['PAY_1', 'PAY_2', 'PAY_3' , 'PAY_4' , 'PAY_5' ,
        'PAY_6' , 'BILL_AMT6' , 'BILL_AMT5' , 'BILL_AMT4' , 'BILL_AMT3' , 'BILL_AMT2' , 
        'BILL_AMT1' , 'PAY_AMT6' , 'PAY_AMT5' , 'PAY_AMT4' , 'PAY_AMT3' , 'PAY_AMT2' , 'PAY_AMT1'])
Cor_data
#corrMat = Cor_data.corr()
#print(corrMat)
# Out:
#        LIMIT_BAL     SEX    EDUCATION  MARRIAGE  AGE  \
# 0          20000  female   university         1   24
# 1         120000  female   university         2   26
# 2          90000  female   university         2   34
# 3          50000  female   university         1   37
# 4          50000    male   university         1   57
# ...          ...     ...          ...       ...  ...
# 29960     220000    male  high school         1   39
# 29961     150000    male  high school         2   43
# 29962      30000    male   university         2   37
# 29963      80000    male  high school         1   41
# 29964      50000    male   university         1   46
#
#       default payment next month
# 0                        default
# 1                        default
# 2                    not default
# 3                    not default
# 4                    not default
# ...                          ...
# 29960                not default
# 29961                not default
# ...

# %%
# Set up new column variables for three objects
Cor_data['gendercode'] = 1
Cor_data['edcode'] = 1
Cor_data['defaultcode'] = 1

#method 2 
#Cor_data.loc[:,'gendercode'] = 0

i=0
j=0
k=0

for i in range(len(Cor_data)):
    if Cor_data.iloc[i,1] == "male":
        Cor_data.iloc[i,6]=2

for j in range(len(Cor_data)):
    if Cor_data.iloc[j,2] == "graduate school":
        Cor_data.iloc[j,7]=4
    elif Cor_data.iloc[j,2] == "university":
        Cor_data.iloc[j,7]=3
    elif Cor_data.iloc[j,2] == "high school":
        Cor_data.iloc[j,7]=2
    else:
         Cor_data.iloc[j,7]=1       

for k in range(len(Cor_data)):
    if Cor_data.iloc[k,5] == "default":
        Cor_data.iloc[k,8]=2
            
Cor_data.head(25)
# Out:
#     LIMIT_BAL     SEX        EDUCATION  MARRIAGE  AGE  \
# 0       20000  female       university         1   24
# 1      120000  female       university         2   26
# 2       90000  female       university         2   34
# 3       50000  female       university         1   37
# 4       50000    male       university         1   57
# 5       50000    male  graduate school         2   37
# 6      500000    male  graduate school         2   29
# 7      100000  female       university         2   23
# 8      140000  female      high school         1   28
# 9       20000    male      high school         2   35
# 10     200000  female      high school         2   34
# 11     260000  female  graduate school         2   51
# 12     630000  female       university         2   41
# 13      70000    male       university         2   30
# 14     250000    male  graduate school         2   29
# 15      50000  female      high school         3   23
# ...

# %%
#drop the obj variables.
Cor_data = Cor_data.drop(axis=1, columns=['SEX', 'EDUCATION', 'default payment next month'])
Cor_data
# Out:
#        LIMIT_BAL  MARRIAGE  AGE  gendercode  edcode  defaultcode
# 0          20000         1   24           1       3            2
# 1         120000         2   26           1       3            2
# 2          90000         2   34           1       3            1
# 3          50000         1   37           1       3            1
# 4          50000         1   57           2       3            1
# ...          ...       ...  ...         ...     ...          ...
# 29960     220000         1   39           2       2            1
# 29961     150000         2   43           2       2            1
# 29962      30000         2   37           2       3            2
# 29963      80000         1   41           2       2            2
# 29964      50000         1   46           2       3            2
#
# [29965 rows x 6 columns]

# %%
Cor_data.describe()
# Out:
#             LIMIT_BAL      MARRIAGE           AGE    gendercode        edcode  \
# count    29965.000000  29965.000000  29965.000000  29965.000000  29965.000000
# mean    167442.005006      1.551877     35.487969      1.396262      3.157250
# std     129760.135222      0.521997      9.219459      0.489128      0.744513
# min      10000.000000      0.000000     21.000000      1.000000      1.000000
# 25%      50000.000000      1.000000     28.000000      1.000000      3.000000
# 50%     140000.000000      2.000000     34.000000      1.000000      3.000000
# 75%     240000.000000      2.000000     41.000000      2.000000      4.000000
# max    1000000.000000      3.000000     79.000000      2.000000      4.000000
#
#         defaultcode
# count  29965.000000
# mean       1.221258
# std        0.415101
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000

# %%
# no correlation
corrMat = Cor_data.corr()
print(corrMat)
# Out:
#              LIMIT_BAL  MARRIAGE       AGE  gendercode    edcode  defaultcode
# LIMIT_BAL     1.000000 -0.108081  0.144643   -0.025015  0.230828    -0.153871
# MARRIAGE     -0.108081  1.000000 -0.413901    0.031372  0.149210    -0.024019
# AGE           0.144643 -0.413901  1.000000    0.091057 -0.182466     0.013619
# gendercode   -0.025015  0.031372  0.091057    1.000000  0.013638     0.039742
# edcode        0.230828  0.149210 -0.182466    0.013638  1.000000    -0.033862
# defaultcode  -0.153871 -0.024019  0.013619    0.039742 -0.033862     1.000000

# %%
#profiling report, does not show any predictable correlations
profile = pandas_profiling.ProfileReport(Cor_data)
profile.to_file("c:\\users\johne\Documents\Purdue DA\Analysis_2.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#rerun new code variables with all 24 variables
All_data = Cdata
All_data['gendercode'] = 1
All_data['edcode'] = 1
All_data['defaultcode'] = 1

#method 2 
#Cor_data.loc[:,'gendercode'] = 0

i=0
j=0
k=0

for i in range(len(All_data)):
    if All_data.iloc[i,1] == "female":
        All_data.iloc[i,24]=2

for j in range(len(Cor_data)):
    if All_data.iloc[j,2] == "graduate school":
        All_data.iloc[j,25]=1
    elif All_data.iloc[j,2] == "university":
        All_data.iloc[j,25]=2
    elif All_data.iloc[j,2] == "high school":
        All_data.iloc[j,25]=3
    else:
         All_data.iloc[j,25]=4       

for k in range(len(Cor_data)):
    if All_data.iloc[k,23] == "default":
        All_data.iloc[k,26]=2
            

All_data = All_data.drop(axis=1, columns=['SEX', 'EDUCATION', 'default payment next month'])
All_data
            
# print(All_data.head(5))
# print(All_data.iloc[0:5,4:5])
# Out:
#        LIMIT_BAL  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# 0          20000         1   24      2      2     -1     -1     -2     -2
# 1         120000         2   26     -1      2      0      0      0      2
# 2          90000         2   34      0      0      0      0      0      0
# 3          50000         1   37      0      0      0      0      0      0
# 4          50000         1   57     -1      0     -1      0      0      0
# ...          ...       ...  ...    ...    ...    ...    ...    ...    ...
# 29960     220000         1   39      0      0      0      0      0      0
# 29961     150000         2   43     -1     -1     -1     -1      0      0
# 29962      30000         2   37      4      3      2     -1      0      0
# 29963      80000         1   41      1     -1      0      0      0     -1
# 29964      50000         1   46      0      0      0      0      0      0
#
#        BILL_AMT6  ...  BILL_AMT1  PAY_AMT6  PAY_AMT5  PAY_AMT4  PAY_AMT3  \
# ...

# %%
#Use groupby to look at trends and convert to data frame.
GBdata = All_data.groupby(['edcode', 'MARRIAGE']). mean().reset_index()

g1=[]
new_data = []
extracted_col = []

#   ***** .reset_index****** to convert to df
#convert series group by data to dataframe.
g1 = All_data.groupby( [ 'edcode', 'MARRIAGE'] ).size().reset_index()


extracted_col = GBdata["defaultcode"]
g1.insert(2, "defaultcode", extracted_col)
g1.rename({0: "Qty per Category"}, axis=1, inplace=True)

print('Groupby data sorted on edcode and then marriage: column1/column2')
print('edcode 1 = Grad School, 2 = University, 3 = High School, 4 = Other')
print('Marriage 1 = married, 2 = single, 3 = divorced, 0 = other','\n')
print(g1)
print('                                     Total = ',g1[ "Qty per Category"].sum(),'\n')

print('The default code column is average of the default code in each grouped category')
print('The default code of 1 = no default so the higher the number, the greater the percentage in each group by category')
print('The only low numbers (closest to 1.0 are in groups with small sample size and not significant)')
print('Nothing predictive with this grouping')
# Out:
# Groupby data sorted on edcode and then marriage: column1/column2
# edcode 1 = Grad School, 2 = University, 3 = High School, 4 = Other
# Marriage 1 = married, 2 = single, 3 = divorced, 0 = other
#
#     edcode  MARRIAGE  defaultcode  Qty per Category
# 0        1         0     1.000000                 4
# 1        1         1     1.206033              3713
# 2        1         2     1.184520              6796
# 3        1         3     1.260000                50
# 4        2         0     1.166667                 6
# 5        2         1     1.243563              6836
# 6        2         2     1.230649              7015
# 7        2         3     1.271605               162
# 8        3         0     1.090909                44
# 9        3         1     1.263636              2860
# 10       3         2     1.236897              1908
# 11       3         3     1.262136               103
# 12       4         1     1.072650               234
# ...

# %%
GB2data = All_data.groupby(['AGE', 'LIMIT_BAL']). mean()
GB2data
# Out:
#                MARRIAGE     PAY_1     PAY_2     PAY_3     PAY_4     PAY_5  \
# AGE LIMIT_BAL
# 21  10000      2.000000  0.333333  0.066667  0.333333  0.066667 -0.333333
#     20000      1.892857  0.071429  0.000000  0.250000  0.035714 -0.428571
#     30000      1.777778  0.444444  0.333333  0.111111  0.000000 -0.111111
#     50000      1.800000 -0.400000 -0.200000 -0.200000 -0.200000 -0.200000
#     60000      2.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...                 ...       ...       ...       ...       ...       ...
# 74  160000     1.000000  0.000000  0.000000  0.000000 -1.000000 -1.000000
# 75  180000     1.000000  1.000000 -2.000000 -2.000000 -2.000000 -2.000000
#     210000     1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#     250000     1.000000  0.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 79  440000     1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...
